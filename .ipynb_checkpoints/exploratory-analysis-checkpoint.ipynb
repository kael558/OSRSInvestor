# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
# %matplotlib inline
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
rune_data_df = pd.read_csv("data/Rune_data.csv")
xp_data_df = pd.read_csv("data/XP_data.csv")

print(rune_data_df.head())
print(xp_data_df.head())
# Out:
#       timestamp  Fire_rune  Water_rune  Air_rune  Earth_rune  Mind_rune  \
# 0  1.613077e+09          5           5         5           5          3
# 1  1.613164e+09          5           5         5           5          3
# 2  1.613250e+09          5           4         4           4          2
# 3  1.613337e+09          5           5         5           4          2
# 4  1.613423e+09          5           5         5           5          3
#
#    Body_rune  Death_rune  Nature_rune  Chaos_rune  Law_rune  Cosmic_rune  \
# 0          5         204          185          52       138          152
# 1          5         204          186          52       142          160
# 2          5         205          186          52       144          160
# 3          5         206          186          52       144          167
# 4          5         207          187          52       145          172
#
#    Blood_rune  Soul_rune
# 0         398        143
# 1         398        144
# 2         397        143
# 3         395        142
# 4         393        142
#       timestamp  runecrafting          magic      fletching   woodcutting  \
# 0  1.613077e+09  57029.584218   92281.394817  105231.221485  83268.002978
# 1  1.613164e+09  54662.911427   98539.698229   90618.685756  88376.703313
# 2  1.613250e+09  55051.024226   98504.279106   91950.110559  79378.655045
# 3  1.613337e+09  52270.260985  108364.283447   90318.916031  74560.453264
# 4  1.613423e+09  52856.244939  102305.191142   85315.045000  83608.821856
#
#      firemaking  construction       farming      herblore      thieving  \
# 0  66504.353566  57599.865254  87144.516653  62638.324107  50468.870287
# 1  68903.235105  52758.278970  87633.689157  72094.052489  43214.904239
# 2  66066.396925  62331.984456  92914.584190  74036.609155  55018.991479
# 3  64970.959885  75727.004532  95195.626073  67212.835834  57297.510526
# 4  59629.406968  76653.900879  89877.351133  63253.140399  54380.451238
#
#          mining      smithing
# 0  47737.540673  74249.280466
# 1  50107.702497  73305.672614
# 2  50974.086498  83712.247378
# 3  47526.202232  88525.301165
# 4  48246.973870  77906.524620

# %%
sns.boxplot(x=rune_data_df['Chaos_rune'])
# Out:
# <AxesSubplot:xlabel='Chaos_rune'>

# %%
plt.figure(figsize=(20,10))
c=rune_data_df.corr()
sns.heatmap(c, annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
d=xp_data_df.corr()
sns.heatmap(d, annot=True)
# Out:
# <AxesSubplot:>
